# %% [markdown]
# <a href="https://colab.research.google.com/github/delgadojoseph271/chat_bot/blob/develop/bodega.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bodega = {"sedan":
          {"Nissan Sentra 2022":
           {"Motor":"149 caballos de fuerza",
           
            "Rango de precio":[ "19,950 - 22,700"],
            "consumo": "39 MPG ",
            "tipo" : "gasolina",
            "Plazas" : "5",
            "transmicion": "automatico",
            },
           "Honda Accord":{
            "Motor":"192 caballos de fuerza",
            
            "Rango de precio":[ "26,520 - 38,450"],
            "consumo": "47 MPG ",
            "tipo": "Hibrido ",
            "Plazas": "5",
            "transmicion": "automatico"
            },
           "Toyota Corolla":{
            "Potencia":"122 caballos de fuerza",
            
            "Rango de precio":[ "26,520 - 38,450"],
            "consumo": "47 MPG ",
            "tipo": "Hibrido ",
            "Plazas": "5",
            "transmicion": "automatico"
            },
           },
          "Pickup":{
              "Toyota Hilux":{
            "Potencia":"122 caballos de fuerza",
            
            "Rango de precio":[ "45,300 - 48,000"],
            "consumo": "26,72 MPG ",
            "tipo": "Disel ",
            "Plazas": "2",
            "transmicion": "automatico"
                  
              },
              "Ford Ranger":{
            "Potencia":"122 caballos de fuerza",
            
            "Rango de precio":[ "45,300 - 48,000"],
            "consumo": "24,24 MPG",
            "tipo": "Disel ",
            "Plazas": "5",
            "transmicion": "manual"
                  
              },
               "isuzu d'max":{
            "Potencia":"122 caballos de fuerza",
            
            "Rango de precio":["71,000"],
            "consumo": "14,9 MPG",
            "tipo": "Disel ",
            "Plazas": "5",
            "transmicion": "manual"      
              }


          },
            "Camionetas":{
              "Honda HR-V":{
            "Potencia":" 119 caballos de fuerza",
            
            "Rango de precio":[ "26,990 - 30,990"],
            "consumo": "46,1 MPG ",
            "tipo": "Gasolina ",
            "Plazas": "5",
            "transmicion": "manual"
                  
              },
              "Toyota Highlander":{
            "Potencia":"122 caballos de fuerza",
            
            "Rango de precio":[ "36,420 - 46,075"],
            "consumo": "24,1 MPG",
            "tipo": "Gasolina ",
            "Plazas": "5",
            "transmicion": "automatico"
                  
              },
               "Nissan X-Trail":{
            "Potencia":"163 caballos de de fuerza",
            
            "Rango de precio":["42,160 - 56,510"],
            "consumo": "44,3 MPG",
            "tipo": "híbridas",
            "Plazas": "5",
            "transmicion": "automatico"
            }
            },
           "Coupe":{
              "AUDI E-TRON GT":{
            "Potencia":["476 CV -  598 CV","530 - 646 CV"],
            
            "Rango de precio":[ "106.050 - 146.000"],
            "consumo": " 23,9 kWh/100 kms",
            "tipo": "Eléctrico ",
            "Plazas": "4",
            "transmicion": "automatico"
                  
              },
              "BMW Serie 8":{
            "Potencia":["476 CV -  598 CV","530 - 646 CV"],
            
            "Rango de precio":[ "103.306 - 198.481"],
            "consumo": "333 - 340 CV",
            "tipo": "Elecrtico ",                                                                                                                                                                         
    
            "Plazas": "4",
            "transmicion": "automatico"
                  
              },
               "Subaru BRZ":{
            "Potencia":"163 caballos de de fuerza",
            
            "Rango de precio":["42,160 - 56,510"],
            "consumo": "44,3 MPG",
            "tipo": "híbridas",
            "Plazas": "5",
            "transmicion": "automatico"
            },
                  


           },
          "Deportivos":{
              "nissan gtr nismo":{
            "Potencia":["600 CV"],
            
            "Rango de precio":[ "106.050 - 146.000"],
            "consumo": " 19,9 MPG",
            "tipo": "Gasolina ",
            "Plazas": "4",
            "transmicion": "automatico"
                  
              },
              "toyota gr supra ":{
            "Potencia":"Potencia",
            "Rango de precio":[ "103.306 - 198.481"],
            "consumo": "29,0 MPG",
            "tipo": "Elecrtico ",
            "Plazas": "4",
            "transmicion": "automatico"
                  
              },
               "CORVETTE STINGRAY":{
            "Potencia":"495 caballos de de fuerza",
            
            "Rango de precio":["139,999 - 159,999"],
            "consumo": "14,9 MPG",
            "tipo": "gasolina",
            "Plazas": "2",
            "transmicion": "automatico"      


            }
          }
}
print(bodega)
# Out:
# {'sedan': {'Nissan Sentra 2022': {'Motor': '149 caballos de fuerza', 'Rango de precio': ['19,950 - 22,700'], 'consumo': '39 MPG ', 'tipo': 'gasolina', 'Plazas': '5', 'transmicion': 'automatico'}, 'Honda Accord': {'Motor': '192 caballos de fuerza', 'Rango de precio': ['26,520 - 38,450'], 'consumo': '47 MPG ', 'tipo': 'Hibrido ', 'Plazas': '5', 'transmicion': 'automatico'}, 'Toyota Corolla': {'Potencia': '122 caballos de fuerza', 'Rango de precio': ['26,520 - 38,450'], 'consumo': '47 MPG ', 'tipo': 'Hibrido ', 'Plazas': '5', 'transmicion': 'automatico'}}, 'Pickup': {'Toyota Hilux': {'Potencia': '122 caballos de fuerza', 'Rango de precio': ['45,300 - 48,000'], 'consumo': '26,72 MPG ', 'tipo': 'Disel ', 'Plazas': '2', 'transmicion': 'automatico'}, 'Ford Ranger': {'Potencia': '122 caballos de fuerza', 'Rango de precio': ['45,300 - 48,000'], 'consumo': '24,24 MPG', 'tipo': 'Disel ', 'Plazas': '5', 'transmicion': 'manual'}, "isuzu d'max": {'Potencia': '122 caballos de fuerza', 'Rango de pre
# ...
